# %% [markdown]
# # **Movie Dataset Python Assignment**

# %% [markdown]
# ### **Question 1**
# Dataset (`movie.csv`) ko pandas mein load karein aur uske pehle 5 rows display karein.

# %%
import pandas as pd
df = pd.read_csv("movie.csv")
df.head()
# Out:
#                Series_Title Released_Year Certificate  ...           Star1 No_of_Votes        Gross
# 0  The Shawshank Redemption          1994           A  ...     Tim Robbins     2343110   28341469.0
# 1             The Godfather          1972           A  ...   Marlon Brando     1620367  134966411.0
# 2           The Dark Knight          2008          UA  ...  Christian Bale     2303232  534858444.0
# 3    The Godfather: Part II          1974           A  ...       Al Pacino     1129952   57300000.0
# 4              12 Angry Men          1957           U  ...     Henry Fonda      689845    4360000.0
#
# [5 rows x 11 columns]

# %% [markdown]
# ### **Question 2**
# Dataset ka total shape (rows aur columns count) check karke print karein.

# %%
df.shape
# Out:
# (1000, 11)

# %% [markdown]
# ### **Question 3**
# Check karein ki kis kis column mein missing values (null values) hain aur unka exact count kya hai.

# %%
df.isnull().sum()
# Out:
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Meta_score       157
# Director           0
# Star1              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df.Released_Year.int

# %% [markdown]
# ### **Question 4**
# Which movies were released after the year 2000? (Year 2000 ke baad release hone wali movies filter karein).

# %%
after_2000 = df[df["Released_Year"] > 2000]
print(after_2000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 after_2000 = df[df["Released_Year"] > 2000]
#       2 print(after_2000)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6138, in Series._cmp_method(self, other, op)
#    6135 lvalues = self._values
#    6136 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6138 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6140 return self._construct_result(res_values, name=res_name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# ### **Question 5**
# Which movies have an IMDB rating greater than 9? (9 se zyada IMDB rating wali movies display karein).

# %%
high_rating = df[df["IMDB_Rating"] > 9]
high_rating
# Out:
#                Series_Title Released_Year Certificate  ...          Star1 No_of_Votes        Gross
# 0  The Shawshank Redemption          1994           A  ...    Tim Robbins     2343110   28341469.0
# 1             The Godfather          1972           A  ...  Marlon Brando     1620367  134966411.0
#
# [2 rows x 11 columns]

# %% [markdown]
# ### **Question 6**
# How many movies are there for each genre? (Har genre ki total kitni movies hain, count nikalye).

# %%
df.Genre.value_counts()
# Out:
# Genre
# Drama                        85
# Drama, Romance               37
# Comedy, Drama                35
# Comedy, Drama, Romance       31
# Action, Crime, Drama         30
#                              ..
# Adventure, Thriller           1
# Animation, Action, Sci-Fi     1
# Action, Crime, Comedy         1
# Animation, Crime, Mystery     1
# Adventure, Comedy, War        1
# Name: count, Length: 202, dtype: int64

# %% [markdown]
# ### **Question 7**
# Which movies were directed by Christopher Nolan? (Christopher Nolan ki directed saari movies nikalye).

# %%
nolan_movies = df[df["Director"] == "Christopher Nolan"]
nolan_movies
# Out:
#               Series_Title Released_Year Certificate  ...                Star1 No_of_Votes        Gross
# 2          The Dark Knight          2008          UA  ...       Christian Bale     2303232  534858444.0
# 8                Inception          2010          UA  ...    Leonardo DiCaprio     2067042  292576195.0
# 21            Interstellar          2014          UA  ...  Matthew McConaughey     1512360  188020017.0
# 36            The Prestige          2006           U  ...       Christian Bale     1190259   53089891.0
# 63   The Dark Knight Rises          2012          UA  ...       Christian Bale     1516346  448139099.0
# 69                 Memento          2000          UA  ...           Guy Pearce     1125712   25544867.0
# 155          Batman Begins          2005          UA  ...       Christian Bale     1308302  206852432.0
# 573                Dunkirk          2017          UA  ...      Fionn Whitehead      555092  188373161.0
#
# [8 rows x 11 columns]

# %% [markdown]
# ### **Question 8**
# Which movies have 'Drama' mentioned in their genre? ('Drama' genre wali movies ko filter karein).

# %%
drama_movies = df[df.Genre == "Drama"]
drama_movies
# Out:
#                         Series_Title Released_Year Certificate  ...                   Star1 No_of_Votes        Gross
# 0           The Shawshank Redemption          1994           A  ...             Tim Robbins     2343110   28341469.0
# 9                         Fight Club          1999           A  ...               Brad Pitt     1854740   37030102.0
# 17   One Flew Over the Cuckoo's Nest          1975           A  ...          Jack Nicholson      918088  112000000.0
# 20                   Soorarai Pottru          2020           U  ...                  Suriya       54995          NaN
# 40                American History X          1998           R  ...           Edward Norton     1034705    6719864.0
# ..                               ...           ...         ...  ...                     ...         ...          ...
# 933             Synecdoche, New York          2008           R  ...  Philip Seymour Hoffman       83158    3081925.0
# 934                  Mysterious Skin          2004           R  ...            Brady Corbet       65939     697181.0
# 941                        25th Hour          2002           R  ...           Edward Norton      169708   13060843.0
# 946                Y tu mamá también          2001           A  ...           Maribel Verdú      115827   13622333.0
# 981                   On Golden Pond          1981          UA  ...       Katharine Hepburn       27650  119285432.0
#
# [85 rows x 11 columns]

# %% [markdown]
# ### **Question 9**
# How can we sort all movies by IMDB rating in descending order? (Movies ko highest se lowest rating ke mutabiq sort karein).

# %%
sorted_rating = df.sort_values("IMDB_Rating", ascending=False)
sort_rating
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 sorted_rating = df.sort_values("IMDB_Rating", ascending=False)
# ----> 2 sort_rating
#
# NameError: name 'sort_rating' is not defined

# %% [markdown]
# ### **Question 10**
# How can we sort all movies by the number of votes they received? (No_of_Votes ke mutabiq descending order mein sort karein).

# %%
movies = movies.sort_values("No_of_Votes", ascending=False)
print(movies)

# %% [markdown]
# ### **Question 11**
# Which movie has the longest runtime? (Sabse lambi movie ka naam aur runtime minutes mein nikalye).

# %%
longest_movie = movies[movies["Runtime"] == movies["Runtime"].max()]
print(longest_movie[["Series_Title", "Runtime"]])

# %% [markdown]
# ### **Question 12**
# Which movies have Leonardo DiCaprio listed as the first star (Star1)?

# %%
leo_movies = movies[movies["Star1"] == "Leonardo DiCaprio"]
print(leo_movies)

# %% [markdown]
# ### **Question 13**
# What is the average IMDB rating of all movies? (Saari movies ki average rating calculate karein).

# %%
average_rating = movies["IMDB_Rating"].mean()
print(average_rating)

# %% [markdown]
# ### **Question 14**
# Dataset ka poora statistical summary (`describe()` function) display karein.

# %%
print(movies.describe())

# %% [markdown]
# ### **Question 15**
# 'Runtime' column se 'min' text ko hata kar use proper integer (numeric) data type mein convert karein.

# %%
movies["Runtime"] = movies["Runtime"].str.replace(" min", "")
movies["Runtime"] = movies["Runtime"].astype(int)

# %% [markdown]
# ### **Question 16**
# 'Gross' column mein jo missing values (NaN) hain, unko pooray column ke median value se fill (impute) karein.

# %%
median_value = movies["Gross"].median()
movies["Gross"] = movies["Gross"].fillna(median_value)

# %% [markdown]
# ### **Question 17**
# Har 'Certificate' category mein total kitni movies hain? (Value counts nikalye).

# %%
print(movies["Certificate"].value_counts())

# %% [markdown]
# ### **Question 18**
# 'IMDB_Rating' aur 'Meta_score' ke darmiyan correlation coefficient maloom karein.

# %%
correlation = movies["IMDB_Rating"].corr(movies["Meta_score"])
print(correlation)

# %% [markdown]
# ### **Question 19**
# Ek naya column banayein 'Rating_100_Scale' jisme 'IMDB_Rating' ko 10 se multiply kiya gaya ho.

# %%
movies["Rating_100_Scale"] = movies["IMDB_Rating"] * 10
print(movies.head())

# %% [markdown]
# ### **Question 20**
# Year 1990 se 2000 (both inclusive) ke darmiyan release hone wali movies ki total count aur list nikaleyin.

# %%
movies_list = movies[
    (movies["Released_Year"] >= 1990) &
    (movies["Released_Year"] <= 2000)
]

print(movies_list)
print("Total Movies:", len(movies_list))

# %% [markdown]
# ### **Question 21**
# (Visualization) IMDB_Rating ka distribution dekhne ke liye ek neat Histogram plot karein.

# %%
import matplotlib.pyplot as plt

plt.hist(movies["IMDB_Rating"])
plt.title("IMDB Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### **Question 22**
# (Visualization) Top 10 Directors aur unki total movies ka ek attractive Bar Chart banayein.

# %%
top_directors = movies["Director"].value_counts().head(10)

top_directors.plot(kind="bar")
plt.show()

# %% [markdown]
# ### **Question 23**
# (Visualization) IMDB_Rating aur Gross revenue ke darmiyan ek Scatter Plot banayein taake dono ka relation dikhe.

# %%
plt.scatter(movies["IMDB_Rating"], movies["Gross"])
plt.xlabel("IMDB Rating")
plt.ylabel("Gross")
plt.show()

# %% [markdown]
# ### **Question 24**
# (Visualization) Genres ka count dekhne ke liye top 5 genres ka ek clean Pie Chart banayein.

# %%
genres = movies["Genre"].str.split(",").explode()

genres.value_counts().head(5).plot(kind="pie", autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ### **Question 25**
# (Visualization) Meta_score ka distribution aur outliers check karne ke liye ek Box Plot banayein.

# %%
avg = movies.groupby("Certificate")["Gross"].mean()

avg.plot(kind="bar")
plt.show()

# %% [markdown]
# ### **Question 26**
# (Visualization) Dataset mein 'Certificate' wise average 'Gross' kamai ka ek Bar Plot banayein.

# %%
avg = movies.groupby("Certificate")["Gross"].mean()

avg.plot(kind="bar")
plt.show()

# %% [markdown]
# ### **Question 27**
# (Visualization) Har saal (Released_Year) kitni movies release hueen, iska ek Line Plot banayein.

# %%
year_data = movies["Released_Year"].value_counts().sort_index()

year_data.plot(kind="line")
plt.show()

# %% [markdown]
# ### **Question 28**
# (Visualization) 'No_of_Votes' ke mutabiq top 5 highest voted movies ka ek Horizontal Bar Chart banayein.

# %%
top5 = movies.sort_values("No_of_Votes", ascending=False).head(5)

plt.barh(top5["Series_Title"], top5["No_of_Votes"])
plt.show()

# %% [markdown]
# ### **Question 29**
# Har movie ke 'Genre' column ko split karke check karein ki total unique genres pure dataset mein kitne hain.

# %%
genres = movies["Genre"].str.split(",").explode()

print(genres.nunique())
print(genres.unique())

# %% [markdown]
# ### **Question 30**
# Dataset ko poora clean karne ke baad safely ek nayi csv file 'cleaned_movies.csv' ke naam se save karein.

# %%
movies.to_csv("cleaned_movies.csv", index=False)

# %% [markdown]
# ### **Question 31**
# Kaunsi movies hain jinki 'IMDB_Rating' 8.5 se zyada hai AUR unka 'Gross' revenue 100 million (100,000,000) se zyada hai? (Dual condition filter)

# %%
result = movies[
    (movies["IMDB_Rating"] > 8.5) &
    (movies["Gross"] > 100000000)
]

print(result)

# %% [markdown]
# ### **Question 32**
# Director 'Christopher Nolan' ki un movies ke naam aur release year nikalein jinka 'Runtime' 140 minutes se zyada hai.

# %%
result = movies[
    (movies["Director"] == "Christopher Nolan") &
    (movies["Runtime"] > 140)
]

print(result[["Series_Title", "Released_Year"]])

# %% [markdown]
# ### **Question 33**
# Aise actors (Star1) ki list nikalein jinhone 'Action' ya 'Sci-Fi' genre mein kaam kiya hai AUR unki movies ki 'IMDB_Rating' kam az kam 8.0 hai.

# %%
result = movies[
    (
        movies["Genre"].str.contains("Action") |
        movies["Genre"].str.contains("Sci-Fi")
    ) &
    (movies["IMDB_Rating"] >= 8.0)
]

print(result["Star1"].unique())

# %% [markdown]
# ### **Question 34**
# Year 2010 se 2020 ke darmiyan release hone wali un movies ka data filter karein jinko Certificate 'UA' ya 'A' mila hai.

# %%
result = movies[
    (movies["Released_Year"] >= 2010) &
    (movies["Released_Year"] <= 2020) &
    (
        (movies["Certificate"] == "UA") |
        (movies["Certificate"] == "A")
    )
]

print(result)

# %% [markdown]
# ### **Question 35**
# Dataset mein 'Meta_score' 90 se zyada aur 'IMDB_Rating' 8.5 se kam wali unique movies kaunsi hain?

# %%
result = movies[
    (movies["Meta_score"] > 90) &
    (movies["IMDB_Rating"] < 8.5)
]

print(result["Series_Title"].unique())

# %% [markdown]
# ### **Question 36**
# (Visualization) 'Drama' aur 'Action' genres ki movies ke 'Gross' revenue ko compare karne ke liye ek Grouped Box Plot ya Violin Plot banayein.

# %%
data = movies[
    movies["Genre"].str.contains("Drama|Action", na=False)
]

data.boxplot(column="Gross", by="Genre")
plt.show()

# %% [markdown]
# ### **Question 37**
# Har Director ki un movies ka count maloom karein jinhone 'No_of_Votes' 500,000 (5 lakh) se zyada hasil kiye hain.

# %%
popular_movies = movies[movies["No_of_Votes"] > 500000]

director_count = popular_movies["Director"].value_counts()

print(director_count)

# %% [markdown]
# ### **Question 38**
# Un movies ke naam aur ratings batayein jinka 'Released_Year' 2000 se pehle ka hai AUR unka 'Gross' unke overall median gross se zyada hai.

# %%
median_gross = movies["Gross"].median()

result = movies[
    (movies["Released_Year"] < 2000) &
    (movies["Gross"] > median_gross)
]

print(result[["Series_Title", "IMDB_Rating"]])

# %% [markdown]
# ### **Question 39**
# Aisi movies ka data nikalein jahan 'Star1' (Main Actor) aur 'Director' dono bilkul same person hain.

# %%
same_person = movies[movies["Star1"] == movies["Director"]]

print(same_person)

# %% [markdown]
# ### **Question 40**
# (Visualization) Top 5 highest rated movies aur unke 'Meta_score' vs 'IMDB_Rating' (scaled to 100) ka ek Side-by-Side Comparison Bar Chart banayein.

# %%
import matplotlib.pyplot as plt

top5 = movies.sort_values("IMDB_Rating", ascending=False).head(5)

imdb = top5["IMDB_Rating"] * 10
meta = top5["Meta_score"]

x = range(len(top5))

plt.figure(figsize=(8, 5))

plt.bar(x, imdb, width=0.4, label="IMDB x10")
plt.bar([i + 0.4 for i in x], meta, width=0.4, label="Meta Score")

plt.xticks([i + 0.2 for i in x], top5["Series_Title"], rotation=45)

plt.xlabel("Movies")
plt.ylabel("Score")
plt.title("Top 5 Movies Comparison")
plt.legend()

plt.tight_layout()
plt.show()
